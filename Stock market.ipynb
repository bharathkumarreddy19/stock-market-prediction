# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORT DATASET

# %%
data = pd.read_csv("S&P500_Stock_Data.csv")

# %%
data
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 0          1.943859   55.413571    2206.680582
# 1          2.258229   59.546305    2486.474488
# 2          2.215863   57.414687    2405.868337
# 3          1.977960   49.908353    2140.434475
# 4          2.437723   52.035492    2411.275663
# ..              ...         ...            ...
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786
#
# [1000 rows x 3 columns]

# %%
data.describe()
# Out:
#        Interest Rates   Employment  S&P 500 Price
# count     1000.000000  1000.000000    1000.000000
# mean         2.195392    56.254855    2319.999936
# std          0.241630     4.862178     193.854745
# min          1.500000    40.000000    1800.000000
# 25%          2.035735    53.029784    2190.447901
# 50%          2.198214    56.160941    2312.443024
# 75%          2.359061    59.422633    2455.764327
# max          3.000000    70.000000    3000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
# Interest Rates    1000 non-null float64
# Employment        1000 non-null float64
# S&P 500 Price     1000 non-null float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %%
data.shape
# Out:
# (1000, 3)

# %% [markdown]
# # VISUALISING DATA

# %%
sns.pairplot(data=data)

# %%
sns.jointplot(x='Interest Rates',y='Employment',data=data)

# %%
sns.jointplot(x='Interest Rates',y='S&P 500 Price',data=data)

# %%
sns.jointplot(x='Employment',y='S&P 500 Price',data=data)

# %% [markdown]
# # SPLITING DATA INTO TRAINING AND TESTING DATASETS

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
X
# Out:
# array([[ 1.94385927, 55.41357113],
#        [ 2.25822894, 59.54630512],
#        [ 2.21586278, 57.41468676],
#        ...,
#        [ 2.00964367, 57.00435706],
#        [ 2.20165596, 62.44779038],
#        [ 2.18063797, 46.29703432]])

# %%
y
# Out:
# array([2206.680582, 2486.474488, 2405.868337, 2140.434475, 2411.275663,
#        2187.344909, 2263.049249, 2281.496374, 2355.163011, 2326.330337,
#        2078.553895, 2337.504507, 2485.774097, 2478.413528, 2665.00807 ,
#        2057.393366, 2423.590565, 2605.470983, 2303.851816, 2095.440317,
#        2495.24303 , 1871.361622, 2213.4959  , 2173.474255, 2505.572687,
#        2394.960918, 2607.334886, 2711.535184, 2287.893451, 2301.183322,
#        2578.928716, 2400.838075, 2513.761261, 2499.709024, 2511.585107,
#        2056.66532 , 2322.506869, 2214.438648, 2293.011223, 2284.377552,
#        2395.449084, 2232.631281, 2486.886187, 2128.56097 , 2330.264882,
#        2179.832793, 2454.376297, 2136.421802, 2218.440607, 2243.357033,
#        2583.772535, 2467.225659, 2306.250551, 2266.485265, 2400.575035,
#        2077.039535, 2615.057826, 2473.534512, 2409.419529, 2365.334582,
#        2380.778616, 2166.298978, 2465.86378 , 2057.81389 , 2479.967865,
# ...

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
X_train.shape
# Out:
# (750, 2)

# %%
X_test.shape
# Out:
# (250, 2)

# %%
y_train.shape
# Out:
# (750,)

# %%
y_test.shape
# Out:
# (250,)

# %% [markdown]
# # TRAINING THE MODEL

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression(fit_intercept = True)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
# Out:
# [724.02102019  11.99389564]

# %%
print(lr.intercept_)
# Out:
# 55.89664313005778

# %% [markdown]
# # EVALUATING THE MODEL

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([1976.86025198, 2117.97301677, 2428.33672735, 2373.36544851,
#        2395.75560371, 2271.83783563, 2609.28501676, 2550.80974549,
#        2446.97345043, 1981.0478872 , 2520.20659348, 2469.5950973 ,
#        2417.77653653, 2410.41549595, 2277.26460214, 2040.17795865,
#        2411.88357093, 2316.19440429, 2583.08176353, 2328.96544906,
#        2470.82738671, 2082.64284843, 2359.19887165, 2130.60878567,
#        2408.74209564, 2339.66748604, 2217.31340925, 2345.95754612,
#        2317.68217678, 2405.09403654, 2661.20620293, 2522.43566313,
#        2301.77330907, 2462.12270249, 2426.97876625, 2369.85399496,
#        2432.06585461, 2146.2823257 , 2429.11309509, 2211.46293926,
#        2190.82064249, 2625.078395  , 2369.36208795, 2287.09468507,
#        2484.83225766, 2487.10738046, 2114.63288742, 2502.36517113,
#        2120.20672046, 2419.11739478, 2101.57474832, 2474.98161513,
#        2146.15019849, 1999.50160254, 2484.44170931, 2448.93973559,
# ...

# %%
y_test
# Out:
# array([1922.893274, 2077.045715, 2286.002432, 2397.280286, 2341.632103,
#        2234.581817, 2711.535184, 2416.199762, 2430.900994, 1898.062783,
#        2535.149493, 2522.769866, 2423.993057, 2401.643137, 2267.103808,
#        2077.039535, 2372.607567, 2295.615096, 2665.00807 , 2255.973064,
#        2400.838075, 2197.061554, 2312.796559, 2091.145495, 2372.415808,
#        2434.409305, 2179.832793, 2303.805232, 2324.146613, 2486.474488,
#        2672.162986, 2461.727516, 2355.333477, 2513.183597, 2352.482742,
#        2448.94019 , 2436.035353, 2138.087162, 2355.530545, 2199.720666,
#        2113.993471, 2573.865933, 2392.917539, 2247.310457, 2560.583189,
#        2604.705284, 2121.392623, 2478.61552 , 1968.758078, 2358.937114,
#        2106.392158, 2500.830946, 2055.510396, 1890.0438  , 2493.42791 ,
#        2412.126316, 2129.542585, 2175.005338, 2718.811585, 1939.696455,
#        2719.577593, 2418.48049 , 2268.189407, 2352.911023, 2540.832079,
# ...

# %%
y_pred.shape
# Out:
# (250,)

# %%
y_test.shape
# Out:
# (250,)

# %%
plt.scatter(y_test,y_pred,color = 'black')
plt.ylabel('Model Predictions')
plt.xlabel('True Values (Ground Truth)')
plt.title('Multiple Linear Regression Predictions')
# Out:
# Text(0.5, 1.0, 'Multiple Linear Regression Predictions')

# %%
k = X_test.shape[1]
n = len(X_test)

# %%
k
# Out:
# 2

# %%
n
# Out:
# 250

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt
MSE = mean_squared_error(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_pred)) , '.3f'))
adj_r2 = 1-(1-r2) * (n-1)/(n-k-1)
MAPE = np.mean( np.abs( (y_test-y_pred) / y_test  )  )*100

# %%
print('RMSE = ', RMSE, '\nMSE =', MSE , '\nMAE =', MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2, '\nMAPE =', MAPE)
# Out:
# RMSE =  61.068
# MSE = 3729.266870596101
# MAE = 49.72033967011997
# R2 = 0.9047740665614054
# Adjusted R2 = 0.9040030063716191
# MAPE = 2.157362990281928

# %% [markdown]
# # VISUALIZE THE RESULTS

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid(np.linspace(data['Interest Rates'].min(),data['Interest Rates'].max(),100), np.linspace(data['Employment'].min(),data['Employment'].max(),100))

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
y_surf.shape
# Out:
# (100, 100)

# %%
x_surf
# Out:
# array([[1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ],
#        [1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ],
#        [1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ],
#        ...,
#        [1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ],
#        [1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ],
#        [1.5       , 1.51515152, 1.53030303, ..., 2.96969697, 2.98484848,
#         3.        ]])

# %%
y_surf
# Out:
# array([[40.        , 40.        , 40.        , ..., 40.        ,
#         40.        , 40.        ],
#        [40.3030303 , 40.3030303 , 40.3030303 , ..., 40.3030303 ,
#         40.3030303 , 40.3030303 ],
#        [40.60606061, 40.60606061, 40.60606061, ..., 40.60606061,
#         40.60606061, 40.60606061],
#        ...,
#        [69.39393939, 69.39393939, 69.39393939, ..., 69.39393939,
#         69.39393939, 69.39393939],
#        [69.6969697 , 69.6969697 , 69.6969697 , ..., 69.6969697 ,
#         69.6969697 , 69.6969697 ],
#        [70.        , 70.        , 70.        , ..., 70.        ,
#         70.        , 70.        ]])

# %%
onlyX = pd.DataFrame({'Interest Rates': x_surf.ravel(),'Employment': y_surf.ravel()})

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
onlyX
# Out:
#       Interest Rates  Employment
# 0           1.500000        40.0
# 1           1.515152        40.0
# 2           1.530303        40.0
# 3           1.545455        40.0
# 4           1.560606        40.0
# ...              ...         ...
# 9995        2.939394        70.0
# 9996        2.954545        70.0
# 9997        2.969697        70.0
# 9998        2.984848        70.0
# 9999        3.000000        70.0
#
# [10000 rows x 2 columns]

# %%
fittedY = lr.predict(onlyX)

# %%
fittedY
# Out:
# array([1621.68399915, 1632.6540146 , 1643.62403006, ..., 3045.59236782,
#        3056.56238327, 3067.53239873])

# %%
fittedY.shape
# Out:
# (10000,)

# %%
fittedY  = fittedY.reshape(x_surf.shape)

# %%
fittedY.shape
# Out:
# (100, 100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['Interest Rates'],data['Employment'],data['S&P 500 Price'],c='blue',marker='x')
ax.plot_surface(x_surf,y_surf,fittedY,color='red',alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_ylabel('Unemployment Rates')
ax.set_zlabel('Stock index price')
# Out:
# Text(0.5, 0, 'Stock index price')

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['Interest Rates'],data['Employment'],data['S&P 500 Price'],c='blue',marker='x')
ax.plot_surface(x_surf,y_surf,fittedY,color='red',alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_ylabel('Unemployment Rates')
ax.set_zlabel('Stock index price')
ax.view_init(60, 70)
plt.show()

# %%
coeff_df = pd.DataFrame(lr.coef_,columns = ['Coefficient'])
coeff_df
# Out:
#    Coefficient
# 0   724.021020
# 1    11.993896
